# %%
import boto3
from bson import json_util
import json
import pandas as pd
import time
from datetime import datetime as dtime
from pytz import timezone

# %%
def get_xml(external_link, frame_height):
    return \
    f"""<ExternalQuestion xmlns="http://mechanicalturk.amazonaws.com/AWSMechanicalTurkDataSchemas/2006-07-14/ExternalQuestion.xsd"><ExternalURL>{external_link}</ExternalURL><FrameHeight>{frame_height}</FrameHeight></ExternalQuestion>"""


production_master_requirement = {
    'QualificationTypeId':'2F1QJWKUDD8XADTFD2Q0G6UTO95ALH',
    'Comparator': 'Exists'
}

worker_locale_rate_requirement = {
    'QualificationTypeId':'00000000000000000071',
    'Comparator': 'EqualTo',
    'LocaleValues': [{'Country':"US"}]
}

worker_approval_rate_requirement = {'QualificationTypeId':'000000000000000000L0',
                                    'Comparator': 'GreaterThanOrEqualTo',
                                    'IntegerValues':[95]}

# %%
# Connect to client

PRODUCTION_MODE = True
AWS_ACCESS_KEY_ID = "AKIAYSSR3P6HBJDFQ4XG"  #  "AKIAYSSR3P6HE2ZWRWI3" # 
AWS_SECRET_ACCESS_KEY = "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" # "LvbAVjddmzDOOvUZEyTLgfkcxT4YNMd01VFdkNit"# 
EXTERNAL_LINK = "https://raven.eecs.harvard.edu:4000/"
FRAME_HEIGHT = 0
REQUESTER_ANNOTATION = 'experiment_run'

environment_list = {
  "production": {
    "endpoint": "https://mturk-requester.us-east-1.amazonaws.com",
    "preview": "https://www.mturk.com/mturk/preview"
  },
  "sandbox": {
    "endpoint": 
          "https://mturk-requester-sandbox.us-east-1.amazonaws.com",
    "preview": "https://workersandbox.mturk.com/mturk/preview"
  },
}

environment = environment_list["production"] if PRODUCTION_MODE else environment_list["sandbox"]

client = boto3.client(
    'mturk',
    endpoint_url=environment['endpoint'],
    region_name='us-east-1',
    aws_access_key_id=AWS_ACCESS_KEY_ID,
    aws_secret_access_key=AWS_SECRET_ACCESS_KEY,
)

print(client.get_account_balance()['AvailableBalance'])
# Out:
# 5431.31

# %%
#time.time() 
#1604259087 + 8 * 3600
currTime = dtime.fromtimestamp(1604287887)
currTime
# Out:
# datetime.datetime(2020, 11, 1, 22, 31, 27)

# %%
all_hits = client.list_hits()['HITs']

#json_string = json.dumps(all_hits, default=json_util.default)
raw_hit_data = pd.DataFrame(all_hits)
#raw_hit_data = pd.read_json(json_string)
#print(type(raw_hit_data.iloc[0]['CreationTime']))


#currTime = dtime.fromtimestamp(1604287887)
#rtn = client.update_expiration_for_hit(HITId='3NOEP8XAU4FQ9DG9HF23BKQOHSYPXG', ExpireAt=currTime)

#now = datetime.datetime.now()
#now = dtime.fromtimestamp(1603173023000/1000.0)
#est_time = now.replace(tzinfo=timezone('EST'))
#date=est_time.strftime("%a, %d %b %Y %H:%M:%S %Z")
#print(date)
#print(raw_hit_data.columns)

raw_hit_data[['HITId', 'RequesterAnnotation', 'CreationTime', 'Expiration', 
              'MaxAssignments', 
              'NumberOfAssignmentsPending', 'NumberOfAssignmentsAvailable', 'NumberOfAssignmentsCompleted',
              'AssignmentDurationInSeconds', 'AutoApprovalDelayInSeconds', 'Reward',
              'HITStatus', 'HITReviewStatus'
             ]]
# Out:
#                             HITId           RequesterAnnotation  \
# 0  3JGHED38ED4Q3C2JQPUOUC6CJ5YY72  experiment_run_2020_11_01_14
# 1  3FVBZG9CLJRQZ6CAVQ5RTX1MLVG0H6  experiment_run_2020_11_01_14
# 2  3NFWQRSHVER3WEWPE26UB4CPCXSFGQ  experiment_run_2020_11_01_14
# 3  3D1UCPY6GGMTNNAEB9T4II6ULOA38P  experiment_run_2020_11_01_14
# 4  3ICOHX7ENCOEFWL85PXL8U49TFOE04  experiment_run_2020_11_01_14
# 5  3SBNLSTU6UI6PBDYDOZT8BPABA6DZ2  experiment_run_2020_11_01_14
# 6  3BFNCI9LYK3PN95V141Y4IAZA44372  experiment_run_2020_11_01_14
# 7  3Y3CZJSZ9K62J7CEO1NXOWZJPCP5RT  experiment_run_2020_11_01_14
# 8  3DW3BNF1GHVDZWCXVJZA1DYDC838VR  experiment_run_2020_11_01_14
# 9  3WRBLBQ2GRLCZAHZBKN98XPL6V30G7  experiment_run_2020_11_01_14
#
#                CreationTime                Expiration  MaxAssignments  \
# 0 2020-11-01 14:38:20-05:00 2020-11-01 22:38:20-05:00               5
# 1 2020-11-01 14:38:19-05:00 2020-11-01 22:38:19-05:00               5
# ...

# %%
### List all assignments of a HIT
all_assignments = client.list_assignments_for_hit(HITId=all_hits[0]['HITId'])['Assignments']
raw_assignment_data = pd.DataFrame(all_assignments)
raw_assignment_data
# Out:
#                      AssignmentId        WorkerId  \
# 0  3FDJT1UU75LIINXDOJJ2C49TDRP5K9   A9HQ3E0F2AGVO
# 1  3KWTYT0871GT2TFV9JV3R4M82RU5LC   AVXEDARJC5HLU
# 2  3WRFBPLXRB1GCEVC7DNPPZSDTQNN3Q  A3BMEVFSETVOUR
# 3  3JW0YLFXRUT3Q66E9YPEQFG1LWFWWT   A4SC8G0149GEG
# 4  30BXRYBRP5ALTGBPEZ3EPC6E68THW5   AQAXDL1INQC9Q
#
#                             HITId AssignmentStatus          AutoApprovalTime  \
# 0  3HFWPF5AK9WB67PNP7Z9Z96VXHRS3M         Approved 2020-10-30 22:08:23-04:00
# 1  3HFWPF5AK9WB67PNP7Z9Z96VXHRS3M         Approved 2020-10-30 22:38:39-04:00
# 2  3HFWPF5AK9WB67PNP7Z9Z96VXHRS3M         Approved 2020-10-30 23:44:59-04:00
# 3  3HFWPF5AK9WB67PNP7Z9Z96VXHRS3M         Approved 2020-10-31 03:56:54-04:00
# 4  3HFWPF5AK9WB67PNP7Z9Z96VXHRS3M         Approved 2020-10-31 04:08:26-04:00
#
#                  AcceptTime                SubmitTime  \
# 0 2020-10-30 20:02:06-04:00 2020-10-30 21:08:23-04:00
# 1 2020-10-30 20:02:23-04:00 2020-10-30 21:38:39-04:00
# ...

# %% [raw]
# ### Create HIT
# #for i in range(10):
#     new_hit = client.create_hit(
#         Title='A science experiment task',
#         Description='''With your help, we hope to improve the ability to forecast replications of social science studies and identify effective tools to obtain confidence on social science claims.
#     Join us to help shape modern social sciences! (Our HITs will keep coming in the following days. You are welcome to complete up to 3 HITs every 12 hours and up to 15 HITs throughout the whole experiment.)''',
#         Keywords='science, experiment, research, social science',
#         Reward='6.00',
#         MaxAssignments=5,
#         LifetimeInSeconds=28800, # 10*60*60
#         AssignmentDurationInSeconds=7200, # 2*60*60
#         AutoApprovalDelayInSeconds=86400, # 24*60*60 = 24 hours
#         RequesterAnnotation = REQUESTER_ANNOTATION+'_'+dtime.now().strftime("%Y_%m_%d_%H"),
#         Question=get_xml(EXTERNAL_LINK, FRAME_HEIGHT),   # <--- this does the trick
#         QualificationRequirements=[
#             production_master_requirement,
#             worker_locale_rate_requirement,
#             worker_approval_rate_requirement
#         ]
#     )

# %%
24*60*60
# Out:
# 86400

# %% [raw]
# response = client.notify_workers(
#     Subject="About your feedback in our HITs about social science studies' replicability",
#     MessageText=\
# """
# Dear Mturk worker,
#
# We are the requester of the HITs about social science studies' replicability. We are delighted to see your sincere feedback provided in the exit survey.
#
# We noticed that you had spent extra efforts working on two additional papers due to our HIT's bug.  We apologize for any trouble made to you and have sent a bonus, equal to another base payment, for compensation. With your help, we have fixed that bug in our paper material preparation.
#
# Also, we noticed that you had spent more than an hour finishing the HIT. We are very interested to know about your feelings about this HIT, for example, about the workload and the base payment amount. If you have any thoughts or experiences you want to share with us, please email at *juntaowang@g.harvard.edu*. We appreciate your sincere responses and feedback for our HITs, and thank you very much for your help.
#
# You are always very welcome to join in our coming HITs and to contact us further!
#
# Yours sincerely,
# Juntao Wang
# Ph.D. Candidate
# Harvard
# """,
#     WorkerIds=['A1V1JNPU0KOA3X']
# )
# print(response)

# %%
"""
Dear Mturk worker,
    
We are the requester of the HITs about social science studies' replicability. We are delighted to see your sincere feedback provided in the exit survey. 

We noticed that you had spent extra efforts working on two additional papers due to our HIT's bug.  We apologize for any trouble made to you and have sent a bonus, equal to another base payment, for compensation. With your help, we have fixed that bug in our paper material preparation. 

Also, we noticed that you had spent more than an hour finishing the HIT. We are very interested to know about your feelings about this HIT, for example, about the workload and the base payment amount. If you have any thoughts or experiences you want to share with us, please email at *juntaowang@g.harvard.edu*. We appreciate your sincere responses and feedback for our HITs, and thank you very much for your help.

You are always very welcome to join in our coming HITs and to contact us further!

Yours sincerely,
Juntao Wang
Ph.D. Candidate
Harvard
"""

# %% [markdown]
# """
# Dear Mturk worker,
#
# We are the requester of the HITs about social science studies' replicability. We are delighted to see your sincere feedback provided in the exit survey.
#
# We noticed that you mentioned in your latest assignment that you didn't feel you did well on this task and were willing to do it again. We are very excited and grateful that you have such a passion for our experiment and would like to know more about your experience in this experiment. In particular, we are very interested in the following information:
# Do you think you provided accurate answers to those multiple-choice questions (like "How much do you understand the main findings/claims of the study after reading the abstract?", "Do you find the main findings/claims surprising?")?
# What factor caused that you didn't feel you did well? Is it because of the time we released the HITs, or the HITs' instruction and design, or your mood at that time? This information will help us a lot.
# What do you think about our estimated time of the HITs and the payment amount?
#
# If you have any thoughts or experiences you want to share with us, please email at *juntaowang@g.harvard.edu* We appreciate your sincere responses and feedback for our HITs, and thank you very much for your help.
#
# Happy Halloween's day!
#
# Yours sincerely,
# Juntao Wang
# Ph.D. Candidate
# Harvard
# """

# %% [raw]
# MessageText=\
# """
# Dear Mturk worker,
#
# We are the requester of HITs of the social science studies' replicability experiment. We are thrilled to know that you tried to contact us using email. We noticed that the email address you got has expired. If you have any thoughts or experiences you want to share with us, please email at juntaowang@g.harvard.edu.
#
# We have also carefully read your exit survey feedback and noticed that you had spent extra efforts working on two additional papers due to our HIT's bug.  We apologize for any trouble made to you and have sent a bonus, equal to another base payment, for compensation.  We appreciate your sincere responses and feedback in our HIT and thank you very much for helping us identify a bug.  You are very welcome to join in our coming HITs and to contact us further. In particular, we are very interested to know about your feelings about the workload and the base payment's amount for such a HIT.
#
# Yours sincerely,
# Juntao Wang
# Ph.D. Candidate
# Harvard
# """
# print(MessageText)

# %% [markdown]
# response = client.send_bonus(
#     WorkerId='A1V1JNPU0KOA3X',
#     BonusAmount='6.00',
#     AssignmentId='3QJOXOW4XK4D4UQ9KWPLVB7AGSVMEF',
#     Reason="We noticed your feedback in the exit survey of our social science replicability experiment. So we bonus you another base payment for the extra two papers you have worked on due to our HIT's bug. Thanks for your sincere work and constructive feedback.",
#     UniqueRequestToken='bonus_for_extra_work_due_to_bugs3QJOXOW4XK4D4UQ9KWPLVB7AGSVMEF'
# )
# response

# %%
8*60*60

# %%
### HIT preview link template
HITId  = "3HRWUH63QUFH49KMVU6GFCU9OBP5NM"
print(f"https://www.mturk.com/mturk/preview?groupId={HITId}")
# Out:
# https://www.mturk.com/mturk/preview?groupId=3HRWUH63QUFH49KMVU6GFCU9OBP5NM

# %%
{ "_id" : "Rrmc72CSAPAdpoXNA", "hitId" : "3OND0WXMHWSPQWR43X46EM3QFE3EHJ" }
{ "_id" : "5A8FBjTZHXf8S6EHP", "hitId" : "3OND0WXMHWSPQWR43X46EM3QFE3EHJ" }
{ "_id" : "bRrPZB2aJNo56juEs", "hitId" : "3VGZ74AYTGTWT2CFN0GT3YRMF2ECGQ" }
{ "_id" : "uCodrMjM6CgD5jbJs", "hitId" : "3OND0WXMHWSPQWR43X46EM3QFE3EHJ" }
{ "_id" : "C4S2synm3rGzSkdns", "hitId" : "3VGZ74AYTGTWT2CFN0GT3YRMF2ECGQ" }
{ "_id" : "3XkxcuAQh64dwY7tK", "hitId" : "39RRBHZ0AUESJSDK49ZNEXVHBZMVZV" }
