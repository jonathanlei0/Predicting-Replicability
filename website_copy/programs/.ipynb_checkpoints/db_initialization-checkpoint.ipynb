# %%
import os
import json
import time
import numpy as np
from pymongo import MongoClient
import hashlib
import argparse

np.set_printoptions(precision=3, suppress=True)

# parser = argparse.ArgumentParser()
# parser.add_argument("port", help="mongodb port to connect", type=int)
# args = parser.parse_args()

# %%
### Hyper-parameters
MAX_ASSIGNMENT_PER_PAPER = 50

# %%
dire = "../public/paper_data/title/"
paper_md5_id_list = []
paper_exp_id_list = []
paper_title_list = []
for file_name in np.sort(os.listdir(dire)):
    if file_name.startswith("[title]"):
        file = open(dire+file_name, 'r')
        title = file.read()
        file.close()
        paper_title_list.append(title)
        paper_exp_id_list.append(int(file_name[7:-4]))
        paper_md5_id_list.append(hashlib.md5(title.encode()).hexdigest())
#        print(file_name)
#        print(title)

paper_md5_id_list = np.array(paper_md5_id_list, dtype=str)
paper_title_list = np.array(paper_title_list, dtype=str)
paper_exp_id_list = np.array(paper_exp_id_list)

paper_order = np.argsort(paper_exp_id_list)
paper_md5_id_list = paper_md5_id_list[paper_order]
paper_exp_id_list = paper_exp_id_list[paper_order]
paper_title_list = paper_title_list[paper_order]

print(np.vstack((paper_exp_id_list, paper_md5_id_list, paper_title_list)).T)
#print(paper_md5_id_list)
print(len(paper_title_list))
# Out:
# [['0' '9a7406852e81c171d4a603dfdf94459c'
#   '"In-Group Love" and "Out-Group Hate" as Motives for Individual Participation in Intergroup Conflict: A New Game Paradigm']
#  ['1' '213dd60cc3d204555c05566e1b08c8a1'
#   '"Walking on Eggshells": How Expressing Relationship Insecurities Perpetuates Them']
#  ['2' '69e83289733fb56a7d5424c92cb77a63'
#   '1/f Noise and Effort on Implicit Measures of Bias']
#  ['3' 'f8774df3e8bffea0a84764dbc01d9c2e'
#   'A Motion Aftereffect From Still Photographs Depicting Motion']
#  ['4' '9b9f220eb1b189ec33b8d9645a6421e6'
#   'A Needs-Based Model of Reconciliation: Satisfying the Differential Emotional Needs of Victim and Perpetrator as a Key to Promoting Reconciliation']
#  ['5' '3d72df405d850dd7fc653d7c177fc75e'
#   'A Single-System Account of the Relationship Between Priming, Recognition, and Fluency']
#  ['6' 'e92b76e7d5d3be0e652d4080dcab5b42'
#   'A Social Functional Approach to Emotions in Bargaining: When Communicating Anger Pays and When It Backfires']
#  ['7' '05081fb9c40e685f7f6b5a74b0ae0f6a'
#   'A Word-Order Constraint on Phonological Activation']
#  ['8' 'ab392a56e8ee20cbf75e0c66ad4a1b36'
#   'Accelerated Relearning After Retrieval-Induced Forgetting: The Benefit of Being Forgotten']
#  ['9' 'c6eaf62c8f7a37d7007f96a11dfbcdee'
#   'Accounting for Occurrences: A New View of the Use of Contingency Information in Causal Judgment']
#  ['10' '4cebfff11f2723be9f550b8b394e506e'
#   'Across-notation Automatic Numerical Processing']
#  ['11' 'c87383f0427b9c9f3737b1f60b5c7625'
#   'Adaptive Memory: The Comparative Value of Survival Processing']
#  ['12' 'd4429319f5a073d43e10b4241a632332'
#   'Affective Incoherence: When Affective Concepts and Embodied Reactions Clash']
#  ['13' 'b84d2ec4b5166f52f266069048a1f49d'
#   'Age-Related Changes in the Episodic Simulation of Future Events']
#  ['14' '070f154362725077374ccfa3dbdd7b67'
#   'An Attention-Based Associative Account of Adjacent and Nonadjacent Dependency Learning']
#  ['15' '80323014672723968abeec6fcbd133f0'
#   'Attractor Dynamics and Semantic Neighborhood Density: Processing Is Slowed by Near Neighbors and Speeded by Distant Neighbors']
#  ['16' 'ac2b9e26b0677adfc0f1d3ab8149f63d'
#   'Auditory Change Detection: Simple Sounds Are Not Memorized Better Than Complex Sounds']
#  ['17' '8a8bc252799865ff1f333107e02d3d67'
#   'Balancing connectedness and self-protection goals in close relationships: a levels-of-processing perspective on risk regulation']
#  ['18' '8537d384f405a210886b7701c0ccb6b7'
#   'Bidirectional Associations in Multiplication Memory: Conditions of Negative and Positive Transfer']
#  ['19' '504cf2fcda4895d881308c328208e0be'
#   'Conflict-Triggered Goal Shielding: Response Conflicts Attenuate Background Monitoring for Prospective Memory Cues']
#  ['20' '9f4a7660a27146429e007c0c4745feeb'
#   'Contextual Effects on Reading Aloud: Evidence for Pathway Control']
#  ['21' 'dcf0541a717b96328271ffa19457c1df'
#   'Creating Social Connection Through Inferential Reproduction: Loneliness and Perceived Agency in Gadgets, Gods, and Greyhounds']
#  ['22' 'a365488426cdbe697b059621998db964'
#   'Decision Making and Learning While Taking Sequential Risks']
#  ['23' '3903c9b30e6fccc3312f0224274ab071'
#   'Detecting the Snake in the Grass: Attention to Fear-Relevant Stimuli by Adults and Young Children']
#  ['24' 'e90ad3a672535939e97f320fbe409339'
#   'Distinguishing Between Silent and Vocal Minorities: Not All Deviants Feel Marginal']
#  ['25' '4a7dea3303dbc2ae206df1ddfc56e449'
#   'Dynamics of Self-Regulation: How (Un)accomplished Goal Actions Affect Motivation']
#  ['26' '36d4d195006a3f2aa73c103076039840'
#   'Effects of Fluency on Psychological Distance and Mental Construal (or Why New York Is a Large City, but <i>New York</i> Is a Civilized Jungle)']
#  ['27' '9310ba6ec6ff5e98439f21cca06245a4'
#   'Errors Are Aversive: Defensive Motivation and the Error-Related Negativity']
#  ['28' '3800b94f1dfda89aeff56e3e618846b2'
#   'Extremal Edge: A Powerful Cue to Depth Perception and Figure-Ground Organization']
#  ['29' 'd66cdf853e5e5a0a08ad30784114c48f'
#   "Head Up, Foot Down: Object Words Orient Attention to the Objects' Typical Location"]
#  ['30' 'f842029b9495d6ae42d74fcb45064396'
#   'Hedonic and Instrumental Motives in Anger Regulation']
#  ['31' '181c7a5531c4c08ec298f93550e292c3'
#   'How Does Bilingualism Improve Executive Control? A Comparison of Active and Reactive Inhibition Mechanisms']
#  ['32' '5efb45c6d1572c05b910a1b0fe6b706a'
#   'How the Head Liberates the Heart: Projection of Communal Responsiveness Guides Relationship Promotion']
#  ['33' '3a7713e8f942ee3924283fd96391328e'
#   'How to Say No: Single- And Dual-Process Theories of Short-Term Recognition Tested on Negative Probes']
#  ['34' '8e1c03e640feadeb630a4e70ee936257'
#   'Implicit Attitude Generalization Occurs Immediately; Explicit Attitude Generalization Takes Time']
#  ['35' '08122cff12efc739aac7f0ea7b2a9405'
#   'Increasing and Decreasing Motor and Cognitive Output: A Model of General Action and Inaction Goals']
#  ['36' '79dc21d0e5943faa63f2baaa12b7b905'
#   'Individual Differences in the Regulation of Intergroup Bias: The Role of Conflict Monitoring and Neural Signals for Control']
#  ['37' 'c46fdb70ff8bbbc53ea762f202d27348'
#   'Intentional Forgetting Is Easier After Two "Shots" Than One']
#  ['38' 'a00ddc2466a3bae0ee67f8cfb544268a'
#   'Is Happiness Having What You Want, Wanting What You Have, or Both?']
#  ['39' '72c0ee111e2750c435b0d526e105aa8f'
#   "Keeping One's Distance: The Influence of Spatial Distance Cues on Affect and Evaluation"]
#  ['40' 'f1de156d68b80ddb7d9bbd0ed6698473'
#   'Learning Correct Responses and Errors in the Hebb Repetition Effect: Two Faces of the Same Coin']
#  ['41' 'ab36a840b14cf20f523d5ae2b5e0bf48'
#   'Left Frontal Cortical Activation and Spreading of Alternatives: Tests of the Action-Based Model of Dissonance']
#  ['42' '46498e6ba6cd2cf5cafe6d0ab116626d'
#   'Modeling Distributions of Immediate Memory Effects: No Strategies Needed?']
#  ['43' '2a41fdd789d06b43425f4bdea6c6231c'
#   'More Than Meets the Eye: The Role of Language in Binding and Maintaining Feature Conjunctions']
#  ['44' 'ae60421044a59fea98a71af2f30768c0'
#   'Multidimensional Visual Statistical Learning']
#  ['45' '65d332e1ee3d8003e232d758e09e3ed5'
#   'Multiple Roles for Time in Short-Term Memory: Evidence From Serial Recall of Order and Timing']
#  ['46' 'a4b670b8dec214cce990f129788b82ba'
#   'Nonconscious Goal Pursuit in Novel Environments: The Case of Implicit Learning']
#  ['47' '7bf7cc3bc09a945adfe6f260147d42d6'
#   "Not So Innocent: Does Seeing One's Own Capacity for Wrongdoing Predict Forgiveness?"]
#  ['48' '46af5c198418023d2b728bf698efaeff'
#   "Now You See It, Now You Don't: Repetition Blindness for Nonwords"]
#  ['49' '3fde33ba2996f34d14670ff07fa503dd'
#   'On the Additive Effects of Stimulus Quality and Word Frequency in Lexical Decision: Evidence for Opposing Interactive Influences Revealed by RT Distributional Analyses']
#  ['50' '3502836a6654695deea5a862fa30dc59'
#   'On the Relative Independence of Thinking Biases and Cognitive Ability']
#  ['51' '2775535b95166e8698f5fde1fab946da'
#   'Opening the Mind to Close It: Considering a Message in Light of Important Values Increases Message Processing and Later Resistance to Change']
#  ['52' 'e36be9d66d25ce405a91940b15d94ab5'
#   'Orienting Attention in Visual Working Memory Reduces Interference From Memory Probes']
#  ['53' 'abaa0d4bbaf9871e6496a8aa5d2c211c'
#   "Perceptual Mechanisms That Characterize Gender Differences in Decoding Women's Sexual Intent"]
#  ['54' '59099d005af73dce56a925186e9fb86d'
#   'Personality Dominance and Preferential Use of the Vertical Dimension of Space: Evidence From Spatial Attention Paradigms']
#  ['55' 'd658666e0d95c38a924d63ed557df57a'
#   'Poignancy: Mixed Emotional Experience in the Face of Meaningful Endings']
#  ['56' '71f3be1f8eb3c8e39c085035c0b5d137'
#   'Precision of the Anchor Influences the Amount of Adjustment']
#  ['57' '26e8c2a6f86189f3de9bd9b50740b514'
#   "Preschoolers' Perspective Taking in Word Learning: Do They Blindly Follow Eye Gaze?"]
#  ['58' '28c9612d997a0245f671580c48a2970f'
#   'Priming Addition Facts With Semantic Relations']
#  ['59' '1fb76b7d262c753709a5eb30edc929c9'
#   "Selective exposure and information quantity: how different information quantities moderate decision makers' preference for consistent and inconsistent information"]
#  ['60' '62f7008c7e5a5e2c8291f35b0a881155'
#   'Self-handicapping, excuse making, and counterfactual thinking: consequences for self-esteem and future motivation']
#  ['61' '2208d3fbb77c169314fd9e3f9a516417'
#   'Self-regulation and selective exposure: the impact of depleted self-regulation resources on confirmatory information processing']
#  ['62' '164dc77f3abeeaf0e58c57094648ac9c'
#   'Semantic Interference in a Delayed Naming Task: Evidence for the Response Exclusion Hypothesis']
#  ['63' 'f1278c3735a1dc8825bbdd920d307363'
#   'Sensitivity to Object Viewpoint and Action Instructions During Search for Targets in the Lower Visual Field']
#  ['64' '76a727ef03f693012d32bd0ec680e4be'
#   'Sex differences in mate preferences revisited: do people know what they initially desire in a romantic partner?']
#  ['65' 'e0333700917d686a0a4e0344d55a6093'
#   'Stereotypes and Retrieval-Provoked Illusory Source Recollections']
#  ['66' 'b7694d121ac74946bb0722d041733097'
#   'Temporal Selection is Suppressed, Delayed, and Diffused During the Attentional Blink']
#  ['67' '338a30dc5411a7288bf7b268e0672ea8'
#   "Terror Management and Adults' Attachment to Their Parents: The Safe Haven Remains"]
#  ['68' '2ab9f2b7ff9babd6e8d6d6844150f06d'
#   'The Best Men Are (Not Always) Already Taken: Female Preference for Single Versus Attached Males Depends on Conception Risk']
#  ['69' '701a482d0417447a810c303bc0163a1c'
#   'The Developmental Psychometrics of Big Five Self-Reports: Acquiescence, Factor Structure, Coherence, and Differentiation From Ages 10 to 20']
#  ['70' 'd86a18381603adb8b4f1b49064c42797'
#   'The Effect of Global Versus Local Processing Styles on Assimilation Versus Contrast in Social Judgment']
#  ['71' '5f68978d8866f32ee1a0c18ac0566b42'
#   'The Effects of an Implemental Mind-Set on Attitude Strength']
#  ['72' '224d17d6525358368c2947eb2b44a3c5'
#   'The Intermixed-Blocked Effect in Human Perceptual Learning Is Not the Consequence of Trial Spacing']
#  ['73' 'a38d459bd3e800ec753bab8beb1fb1dd'
#   'The Nonverbal Expression of Pride: Evidence for Cross-Cultural Recognition']
#  ['74' '286a722457afe72be42c244e1c946663'
#   'The Rejection of Moral Rebels: Resenting Those Who Do the Right Thing']
#  ['75' 'cc0bb8a26cb8809dcc15547966952569'
#   'The Representation of Simple Ensemble Visual Features Outside the Focus of Attention']
#  ['76' '780501eecf46cbb7103cbcc6e35de45b'
#   'The Stroop Effect: Why Proportion Congruent Has Nothing to Do With Congruency and Everything to Do With Contingency']
#  ['77' '78d39e67726592afc3d9cc03c7813831'
#   'The Sunny Side of Fairness: Preference for Fairness Activates Reward Circuitry (and Disregarding Unfairness Activates Self-Control Circuitry)']
#  ['78' 'ff6f79eb77cf9ed32de6924dda93c451'
#   'The Threat of Appearing Prejudiced and Race-Based Attentional Biases']
#  ['79' '5c4918cfb214a1c3c9316b64b5efeabb'
#   'The Ultimate Sampling Dilemma in Experience-Based Decision Making']
#  ['80' '9b8f0a7d00b6ed03bab3c8688f990e2b'
#   'The Value of Believing in Free Will: Encouraging a Belief in Determinism Increases Cheating']
#  ['81' 'a39c566d3f9fd9a86275c956f89f704c'
#   'The space between us: stereotype threat and distance in interracial contexts']
#  ['82' '8b7fb7fb8bb7b51fa5643891b5bb1368'
#   'Toward a Physiology of Dual-Process Reasoning and Judgment: Lemonade, Willpower, and Expensive Rule-Based Analysis']
#  ['83' '539e747f7dd77d2056a2128e6934493a'
#   'Tracing Attention and the Activation Flow of Spoken Word Planning Using Eye Movements']
#  ['84' '42cfa5e4a5d344b518d973bd62958fff'
#   'What Do Cross-National Comparisons of Personality Traits Tell Us?: The Case of Conscientiousness']
#  ['85' 'b853f3c4370f9b25b1d4488dd17f286f'
#   'When Does Between-Sequence Phonological Similarity Promote Irrelevant Sound Disruption?']
#  ['86' 'd58eafb9c8ce9ed75f626a2fb1eb08b4'
#   'Why do implicit and explicit attitude tests diverge? The role of structural fit']
#  ['87' 'e9f615ebd5f061708e70dc8f9a52d833'
#   'With a Clean Conscience: Cleanliness Reduces the Severity of Moral Judgments']
#  ['88' '7bf2d702b97d9aef97086ab7e3e1921e'
#   'Working Memory Costs of Task Switching']]
# 89

# %%
# connect to DB:meteor and fetch the handle of collection:wageringPM
connection = MongoClient("mongodb://127.0.0.1:3001/meteor")

# %%
# recreate the collection
clc = connection.meteor.paper
clc.drop()
for i in range(len(paper_title_list)):
    print(paper_exp_id_list[i], paper_title_list[i])
    entry = {"paper_md5_id": paper_md5_id_list[i],
             "paper_title": paper_title_list[i], 
             "paper_exp_id": int(paper_exp_id_list[i]),
             "paper_assigned_as_first_exp_paper": int(0),
             "paper_completed_as_first_exp_paper": int(0),
             "paper_assigned": int(0),
             "paper_completed": int(0),
             "paper_max_completion": int(MAX_ASSIGNMENT_PER_PAPER) 
            }
    clc.insert_one(entry)
    
clc_hyper_para = connection.meteor.hyperparameter
clc_hyper_para.drop()
clc_hyper_para.insert_one({'max_assign_per_batch_user': 3, 'max_assign_per_user': 15})
# Out:
# 0 "In-Group Love" and "Out-Group Hate" as Motives for Individual Participation in Intergroup Conflict: A New Game Paradigm
# 1 "Walking on Eggshells": How Expressing Relationship Insecurities Perpetuates Them
# 2 1/f Noise and Effort on Implicit Measures of Bias
# 3 A Motion Aftereffect From Still Photographs Depicting Motion
# 4 A Needs-Based Model of Reconciliation: Satisfying the Differential Emotional Needs of Victim and Perpetrator as a Key to Promoting Reconciliation
# 5 A Single-System Account of the Relationship Between Priming, Recognition, and Fluency
# 6 A Social Functional Approach to Emotions in Bargaining: When Communicating Anger Pays and When It Backfires
# 7 A Word-Order Constraint on Phonological Activation
# 8 Accelerated Relearning After Retrieval-Induced Forgetting: The Benefit of Being Forgotten
# 9 Accounting for Occurrences: A New View of the Use of Contingency Information in Causal Judgment
# 10 Across-notation Automatic Numerical Processing
# 11 Adaptive Memory: The Comparative Value of Survival Processing
# 12 Affective Incoherence: When Affective Concepts and Embodied Reactions Clash
# 13 Age-Related Changes in the Episodic Simulation of Future Events
# 14 An Attention-Based Associative Account of Adjacent and Nonadjacent Dependency Learning
# 15 Attractor Dynamics and Semantic Neighborhood Density: Processing Is Slowed by Near Neighbors and Speeded by Distant Neighbors
# 16 Auditory Change Detection: Simple Sounds Are Not Memorized Better Than Complex Sounds
# 17 Balancing connectedness and self-protection goals in close relationships: a levels-of-processing perspective on risk regulation
# 18 Bidirectional Associations in Multiplication Memory: Conditions of Negative and Positive Transfer
# 19 Conflict-Triggered Goal Shielding: Response Conflicts Attenuate Background Monitoring for Prospective Memory Cues
# 20 Contextual Effects on Reading Aloud: Evidence for Pathway Control
# 21 Creating Social Connection Through Inferential Reproduction: Loneliness and Perceived Agency in Gadgets, Gods, and Greyhounds
# 22 Decision Making and Learning While Taking Sequential Risks
# 23 Detecting the Snake in the Grass: Attention to Fear-Relevant Stimuli by Adults and Young Children
# 24 Distinguishing Between Silent and Vocal Minorities: Not All Deviants Feel Marginal
# 25 Dynamics of Self-Regulation: How (Un)accomplished Goal Actions Affect Motivation
# 26 Effects of Fluency on Psychological Distance and Mental Construal (or Why New York Is a Large City, but <i>New York</i> Is a Civilized Jungle)
# 27 Errors Are Aversive: Defensive Motivation and the Error-Related Negativity
# 28 Extremal Edge: A Powerful Cue to Depth Perception and Figure-Ground Organization
# 29 Head Up, Foot Down: Object Words Orient Attention to the Objects' Typical Location
# 30 Hedonic and Instrumental Motives in Anger Regulation
# 31 How Does Bilingualism Improve Executive Control? A Comparison of Active and Reactive Inhibition Mechanisms
# 32 How the Head Liberates the Heart: Projection of Communal Responsiveness Guides Relationship Promotion
# 33 How to Say No: Single- And Dual-Process Theories of Short-Term Recognition Tested on Negative Probes
# 34 Implicit Attitude Generalization Occurs Immediately; Explicit Attitude Generalization Takes Time
# 35 Increasing and Decreasing Motor and Cognitive Output: A Model of General Action and Inaction Goals
# 36 Individual Differences in the Regulation of Intergroup Bias: The Role of Conflict Monitoring and Neural Signals for Control
# 37 Intentional Forgetting Is Easier After Two "Shots" Than One
# 38 Is Happiness Having What You Want, Wanting What You Have, or Both?
# 39 Keeping One's Distance: The Influence of Spatial Distance Cues on Affect and Evaluation
# 40 Learning Correct Responses and Errors in the Hebb Repetition Effect: Two Faces of the Same Coin
# 41 Left Frontal Cortical Activation and Spreading of Alternatives: Tests of the Action-Based Model of Dissonance
# 42 Modeling Distributions of Immediate Memory Effects: No Strategies Needed?
# 43 More Than Meets the Eye: The Role of Language in Binding and Maintaining Feature Conjunctions
# 44 Multidimensional Visual Statistical Learning
# 45 Multiple Roles for Time in Short-Term Memory: Evidence From Serial Recall of Order and Timing
# 46 Nonconscious Goal Pursuit in Novel Environments: The Case of Implicit Learning
# 47 Not So Innocent: Does Seeing One's Own Capacity for Wrongdoing Predict Forgiveness?
# 48 Now You See It, Now You Don't: Repetition Blindness for Nonwords
# 49 On the Additive Effects of Stimulus Quality and Word Frequency in Lexical Decision: Evidence for Opposing Interactive Influences Revealed by RT Distributional Analyses
# 50 On the Relative Independence of Thinking Biases and Cognitive Ability
# 51 Opening the Mind to Close It: Considering a Message in Light of Important Values Increases Message Processing and Later Resistance to Change
# 52 Orienting Attention in Visual Working Memory Reduces Interference From Memory Probes
# 53 Perceptual Mechanisms That Characterize Gender Differences in Decoding Women's Sexual Intent
# 54 Personality Dominance and Preferential Use of the Vertical Dimension of Space: Evidence From Spatial Attention Paradigms
# 55 Poignancy: Mixed Emotional Experience in the Face of Meaningful Endings
# 56 Precision of the Anchor Influences the Amount of Adjustment
# 57 Preschoolers' Perspective Taking in Word Learning: Do They Blindly Follow Eye Gaze?
# 58 Priming Addition Facts With Semantic Relations
# 59 Selective exposure and information quantity: how different information quantities moderate decision makers' preference for consistent and inconsistent information
# 60 Self-handicapping, excuse making, and counterfactual thinking: consequences for self-esteem and future motivation
# 61 Self-regulation and selective exposure: the impact of depleted self-regulation resources on confirmatory information processing
# 62 Semantic Interference in a Delayed Naming Task: Evidence for the Response Exclusion Hypothesis
# 63 Sensitivity to Object Viewpoint and Action Instructions During Search for Targets in the Lower Visual Field
# 64 Sex differences in mate preferences revisited: do people know what they initially desire in a romantic partner?
# 65 Stereotypes and Retrieval-Provoked Illusory Source Recollections
# 66 Temporal Selection is Suppressed, Delayed, and Diffused During the Attentional Blink
# 67 Terror Management and Adults' Attachment to Their Parents: The Safe Haven Remains
# 68 The Best Men Are (Not Always) Already Taken: Female Preference for Single Versus Attached Males Depends on Conception Risk
# 69 The Developmental Psychometrics of Big Five Self-Reports: Acquiescence, Factor Structure, Coherence, and Differentiation From Ages 10 to 20
# 70 The Effect of Global Versus Local Processing Styles on Assimilation Versus Contrast in Social Judgment
# 71 The Effects of an Implemental Mind-Set on Attitude Strength
# 72 The Intermixed-Blocked Effect in Human Perceptual Learning Is Not the Consequence of Trial Spacing
# 73 The Nonverbal Expression of Pride: Evidence for Cross-Cultural Recognition
# 74 The Rejection of Moral Rebels: Resenting Those Who Do the Right Thing
# 75 The Representation of Simple Ensemble Visual Features Outside the Focus of Attention
# 76 The Stroop Effect: Why Proportion Congruent Has Nothing to Do With Congruency and Everything to Do With Contingency
# 77 The Sunny Side of Fairness: Preference for Fairness Activates Reward Circuitry (and Disregarding Unfairness Activates Self-Control Circuitry)
# 78 The Threat of Appearing Prejudiced and Race-Based Attentional Biases
# 79 The Ultimate Sampling Dilemma in Experience-Based Decision Making
# 80 The Value of Believing in Free Will: Encouraging a Belief in Determinism Increases Cheating
# 81 The space between us: stereotype threat and distance in interracial contexts
# 82 Toward a Physiology of Dual-Process Reasoning and Judgment: Lemonade, Willpower, and Expensive Rule-Based Analysis
# 83 Tracing Attention and the Activation Flow of Spoken Word Planning Using Eye Movements
# 84 What Do Cross-National Comparisons of Personality Traits Tell Us?: The Case of Conscientiousness
# 85 When Does Between-Sequence Phonological Similarity Promote Irrelevant Sound Disruption?
# 86 Why do implicit and explicit attitude tests diverge? The role of structural fit
# 87 With a Clean Conscience: Cleanliness Reduces the Severity of Moral Judgments
# 88 Working Memory Costs of Task Switching

# %%
clc.drop()
for i in range(8):
    entry = {"paper_md5_id": "md5_"+str(i),
             "paper_title": "title_"+str(i), 
             "paper_exp_id": int(paper_exp_id_list[i]),
             "paper_assigned_as_first_exp_paper": int(0),
             "paper_completed_as_first_exp_paper": int(0),
             "paper_assigned": int(0),
             "paper_completed": int(0),
             "paper_max_completion": 10
            }
    clc.insert_one(entry)

clc_hyper_para = connection.meteor.hyperparameter
clc_hyper_para.drop()
clc_hyper_para.insert_one({'max_assign_per_batch_user': 3, 'max_assign_per_user': 15})
