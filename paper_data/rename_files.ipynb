# %%
import os
import numpy as np
import re


title_list = []
paper_id = 0
for file_name in np.sort(os.listdir('title/')):
    if file_name[0]=='[': continue
    title_list.append(file_name)
    
title_id_dict = {}
id_title_dict = {}
for i, title in enumerate(title_list):
    #print(title)
    title_id_dict[title] = i
    id_title_dict[i] = title
    file = open(f'title/[title]{i}.txt','w')
    file.write(title)
    file.close()
    
def resort_dir_by_title(directory, title_list, title_id_dict):
    directory = directory.lower()
    for file_name in np.sort(os.listdir(directory)):
        print(file_name)
        pos = file_name.find(']')
        prefix = file_name[: pos+1].lower()
        real_name = file_name[pos+1:].lower()
        file_name_hash = real_name[:20]
        if (not (directory in prefix)) or (real_name[0].isdigit()): continue
        
        print(file_name_hash)
        found = False
        for title in title_list:
            if file_name_hash in title.lower():
                found = True
                paper_id = title_id_dict[title]
                os.rename(f'{directory}/{file_name}',
                          f'{directory}/[{directory}]{paper_id}.txt')
                print('Found!')
        if not found: 
            print(f"Error: Cannot find the title for {file_name}!")
            
resort_dir_by_title('abstract', title_list, title_id_dict)
resort_dir_by_title('method', title_list, title_id_dict)
# Out:
# [abstract]10.txt
# [abstract]11.txt
# [abstract]12.txt
# [abstract]13.txt
# [abstract]16.txt
# [abstract]18.txt
# [abstract]21.txt
# [abstract]22.txt
# [abstract]24.txt
# [abstract]25.txt
# [abstract]26.txt
# [abstract]28.txt
# [abstract]29.txt
# [abstract]3.txt
# [abstract]32.txt
# [abstract]34.txt
# [abstract]35.txt
# [abstract]36.txt
# [abstract]41.txt
# [abstract]44.txt
# [abstract]45.txt
# [abstract]46.txt
# [abstract]47.txt
# [abstract]48.txt
# [abstract]5.txt
# [abstract]6.txt
# [abstract]7.txt
# [abstract]9.txt
# [method first_exp]A single-system account of the relationship between priming, recognition, a...: EBSCOhost.html
# a single-system acco
# Found!
# [method first_exp]Accelerated relearning after retrieval-induced forgetting: The benefit of b...: EBSCOhost.html
# accelerated relearni
# Found!
# [method first_exp]Accounting for occurrences: A new view of the use of contingency informatio...: EBSCOhost.html
# accounting for occur
# Found!
# [method first_exp]Across-notation automatic numerical processing: EBSCOhost.html
# across-notation auto
# Found!
# [method first_exp]An attention-based associative account of adjacent and nonadjacent dependen...: EBSCOhost.html
# an attention-based a
# Found!
# [method first_exp]Attractor dynamics and semantic neighborhood density: Processing is slowed ...: EBSCOhost.html
# attractor dynamics a
# Found!
# [method first_exp]Bidirectional associations in multiplication memory: Conditions of negative...: EBSCOhost.html
# bidirectional associ
# Found!
# [method first_exp]Contextual effects on reading aloud: Evidence for pathway control: EBSCOhost.html
# contextual effects o
# Found!
# [method first_exp]Decision making and learning while taking sequential risks: EBSCOhost.html
# decision making and
# Found!
# [method first_exp]How does bilingualism improve executive control? A comparison of active and...: EBSCOhost.html
# how does bilingualis
# Found!
# [method first_exp]How to say no: Single- and dual-process theories of short-term recognition ...: EBSCOhost.html
# how to say no: singl
# Found!
# [method first_exp]Intentional forgetting is easier after two 'shots' than one: EBSCOhost.html
# intentional forgetti
# Found!
# [method first_exp]Learning correct responses and errors in the Hebb repetition effect: Two fa...: EBSCOhost.html
# learning correct res
# Found!
# [method first_exp]Modeling distributions of immediate memory effects: No strategies needed?: EBSCOhost.html
# modeling distributio
# Found!
# [method first_exp]Multidimensional visual statistical learning: EBSCOhost.html
# multidimensional vis
# Found!
# [method first_exp]Multiple roles for time in short-term memory: Evidence from serial recall o...: EBSCOhost.html
# multiple roles for t
# Found!
# [method first_exp]Now you see it, now you don't: Repetition blindness for nonwords: EBSCOhost.html
# now you see it, now
# Found!
# [method first_exp]On the additive effects of stimulus quality and word frequency in lexical d...: EBSCOhost.html
# on the additive effe
# Found!
# [method first_exp]Orienting attention in visual working memory reduces interference from memo...: EBSCOhost.html
# orienting attention
# Found!
# [method first_exp]Priming addition facts with semantic relations: EBSCOhost.html
# priming addition fac
# Found!
# [method first_exp]Semantic interference in a delayed naming task: Evidence for the response e...: EBSCOhost.html
# semantic interferenc
# Found!
# [method first_exp]Stereotypes and retrieval-provoked illusory source recollections: EBSCOhost.html
# stereotypes and retr
# Found!
# [method first_exp]The Stroop effect: Why proportion congruent has nothing to do with congruen...: EBSCOhost.html
# the stroop effect: w
# Found!
# [method first_exp]The intermixed-blocked effect in human perceptual learning is not the conse...: EBSCOhost.html
# the intermixed-block
# Found!
# [method first_exp]The ultimate sampling dilemma in experience-based decision making: EBSCOhost.html
# the ultimate samplin
# Found!
# [method first_exp]Tracing attention and the activation flow in spoken word planning using eye...: EBSCOhost.html
# tracing attention an
# Found!
# [method first_exp]When does between-sequence phonological similarity promote irrelevant sound...: EBSCOhost.html
# when does between-se
# Found!

# %%
print(len('[abstract]'))
print('2e'.isdigit())
print(title_list)
# Out:
# 10
# False
# ['"Walking on Eggshells": How Expressing Relationship Insecurities Perpetuates Them', '1:f Noise and Effort on Implicit Measures of Bias', 'A Needs-Based Model of Reconciliation: Satisfying the Differential Emotional Needs of Victim and Perpetrator as a Key to Promoting Reconciliation', 'A Single-System Account of the Relationship Between Priming, Recognition, and Fluency', 'A Social Functional Approach to Emotions in Bargaining: When Communicating Anger Pays and When It Backfires', 'Accelerated Relearning After Retrieval-Induced Forgetting: The Benefit of Being Forgotten', 'Accounting for Occurrences: A New View of the Use of Contingency Information in Causal Judgment', 'Across-notation Automatic Numerical Processing', 'Affective Incoherence: When Affective Concepts and Embodied Reactions Clash', 'An Attention-Based Associative Account of Adjacent and Nonadjacent Dependency Learning', 'Attractor Dynamics and Semantic Neighborhood Density: Processing Is Slowed by Near Neighbors and Speeded by Distant Neighbors', 'Bidirectional Associations in Multiplication Memory: Conditions of Negative and Positive Transfer', 'Contextual Effects on Reading Aloud: Evidence for Pathway Control', 'Decision Making and Learning While Taking Sequential Risks', 'Distinguishing Between Silent and Vocal Minorities: Not All Deviants Feel Marginal', 'Dynamics of Self-Regulation: How (Un)accomplished Goal Actions Affect Motivation', 'How Does Bilingualism Improve Executive Control? A Comparison of Active and Reactive Inhibition Mechanisms', 'How the Head Liberates the Heart: Projection of Communal Responsiveness Guides Relationship Promotion', 'How to Say No: Single- And Dual-Process Theories of Short-Term Recognition Tested on Negative Probes', 'Increasing and Decreasing Motor and Cognitive Output: A Model of General Action and Inaction Goals', 'Individual Differences in the Regulation of Intergroup Bias: The Role of Conflict Monitoring and Neural Signals for Control', 'Intentional Forgetting Is Easier After Two "Shots" Than One', 'Learning Correct Responses and Errors in the Hebb Repetition Effect: Two Faces of the Same Coin', 'Left Frontal Cortical Activation and Spreading of Alternatives: Tests of the Action-Based Model of Dissonance', 'Modeling Distributions of Immediate Memory Effects: No Strategies Needed?', 'Multidimensional Visual Statistical Learning', 'Multiple Roles for Time in Short-Term Memory: Evidence From Serial Recall of Order and Timing', "Not So Innocent: Does Seeing One's Own Capacity for Wrongdoing Predict Forgiveness?", "Now You See It, Now You Don't: Repetition Blindness for Nonwords", 'On the Additive Effects of Stimulus Quality and Word Frequency in Lexical Decision: Evidence for Opposing Interactive Influences Revealed by RT Distributional Analyses', 'On the Relative Independence of Thinking Biases and Cognitive Ability', 'Opening the Mind to Close It: Considering a Message in Light of Important Values Increases Message Processing and Later Resistance to Change', 'Orienting Attention in Visual Working Memory Reduces Interference From Memory Probes', 'Poignancy: Mixed Emotional Experience in the Face of Meaningful Endings', 'Priming Addition Facts With Semantic Relations', 'Semantic Interference in a Delayed Naming Task: Evidence for the Response Exclusion Hypothesis', 'Stereotypes and Retrieval-Provoked Illusory Source Recollections', "Terror Management and Adults' Attachment to Their Parents: The Safe Haven Remains", 'The Developmental Psychometrics of Big Five Self-Reports: Acquiescence, Factor Structure, Coherence, and Differentiation From Ages 10 to 20', 'The Effect of Global Versus Local Processing Styles on Assimilation Versus Contrast in Social Judgment', 'The Effects of an Implemental Mind-Set on Attitude Strength', 'The Intermixed-Blocked Effect in Human Perceptual Learning Is Not the Consequence of Trial Spacing', 'The Nonverbal Expression of Pride: Evidence for Cross-Cultural Recognition', 'The Rejection of Moral Re ...
